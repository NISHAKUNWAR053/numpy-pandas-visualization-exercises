# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# Use matplotlib to plot the following equation:
#
# y = x2 − x + 2
#
# You'll need to write the code that generates the x and y points.
#
# Add an anotation for the point 0, 0, the origin.

# %%
# Generate x values
x = np.linspace(-10, 10, 100)  # Generating 100 points from -10 to 10

# Calculate y values using the equation y = x^2 - x + 2
y = x**2 - x + 2

# Create the plot
plt.plot(x, y, label='y = x**2 - x + 2')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Plot of y')
plt.show()
plt.annotate
# Out:
# <function matplotlib.pyplot.annotate(text, xy, xytext=None, xycoords='data', textcoords=None, arrowprops=None, annotation_clip=None, **kwargs)>

# %%
x = np.linspace(0, 5, 100)
y = x**2 - x + 2
plt.plot(x,y, label ='y = x**2 - x + 2')
plt.xlabel('x')
plt.ylabel('y')
plt.title('plot of y = x**2 - x + 2')

plt.show()

# %% [markdown]
# 2. Create and label 4 separate charts for the following equations (choose a range for x that makes sense):

# %%
x = np.linspace(0, 10, 100)
y1 = np.sqrt(x)

# %%
plt.plot(x, y1, label="y = .sqrt(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Square Root Function")
plt.legend()

# %%
y2 = x ** 3

# %%
plt.plot(x, y2, label="y = x**3")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Cubic Function")
plt.show()

# %%
y3 = 2 * x

# %%
plt.plot(x, y3, label="y = 2x")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Linear Function")
plt.legend()

# %%
y4 = 1 / (x + 1)

# %%
plt.plot(x, y4, label="y = 1 / (x + 1)")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Rational Function")
plt.legend()

# %% [markdown]
# Combine the figures you created in the last step into one large figure with 4 subplots.

# %%
x = np.linspace(0, 11, 100)
plt.figure(figsize=(20, 4))

#define my first subplot
plt.subplot(1,4,1)
plt.plot(x, y1, label="y = .sqrt(x)")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Square Root Function")


#define my second subplot
plt.subplot(1,4,2)
plt.plot(x, y2, label="y = x**3")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Cubic Function")


#define my third subplot
plt.subplot(1,4,3)
plt.plot(x, y3, label="y = 2x")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Linear Function")


#define my fourth subplot
plt.subplot(1,4,4)
plt.plot(x, y4, label="y = 1 / (x + 1)")
plt.xlabel("x")
plt.ylabel("y")
plt.title("Rational Function")
# Out:
# Text(0.5, 1.0, 'Rational Function')

# %% [markdown]
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
plt.plot(x, y1, c='#30a2da', label='$\sqrt{x}$', alpha=1)
plt.plot(x, y2, c='orange', label='$x^{3}$', alpha=1)
plt.plot(x, y3, c= (1,0,1), label='$2^{x}$', alpha=1)
plt.plot(x, y4, c= '#444444', label='$1/(x+1)$', alpha=1)

# Adjust xlim and ylim
plt.ylim(0, 10)
plt.xlim(0, 10)

plt.ylabel('$y$')
plt.xlabel('$x$')
plt.title('Combined Charts')
plt.legend()

plt.show()
